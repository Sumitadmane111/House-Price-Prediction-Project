# %% [markdown]
# # machine learning project with Iris Flower dataset

# %%
#dataset of iris is about flower part length

# %% [raw]
# 1. Sepal length in cm
# 2. Sepal width in cm
# 3. Petal length in cm
# 4. Petal width in cm

# %% [markdown]
# # Classify Iris Flower
# Versicolor
# Virginica
# Setosa

# %%
#load data
import pandas as pd
df=pd.read_csv("C:\\Users\\shree kalika\\Downloads\\Iris.csv")
print(df)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # data undastanding

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %% [markdown]
# # # top

# %%
print(df.head(5))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # down

# %%
print(df.tail(5))
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# # describe

# %%
print(df.describe)
print(df.shape)
# Out:
# <bound method NDFrame.describe of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %% [markdown]
# # #data preprocessing
# #count instances of each to find missing data and value count
# - all value is
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
print(df.isnull().sum())#no missing value
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
print(df['SepalLengthCm'].value_counts())
print(df['SepalWidthCm'].value_counts())
print(df['PetalLengthCm'].value_counts())
print(df['Species'].value_counts())
# Out:
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: SepalLengthCm, dtype: int64
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.6     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: SepalWidthCm, dtype: int64
# 1.5    14
# 1.4    12
# 5.1     8
# 4.5     8
# 1.6     7
# 1.3     7
# 5.6     6
# 4.7     5
# 4.9     5
# 4.0     5
# 4.2     4
# 5.0     4
# 4.4     4
# 4.8     4
# 1.7     4
# 3.9     3
# 4.6     3
# 5.7     3
# 4.1     3
# ...

# %% [markdown]
# # #find x and y
# x=input value
# y=output value

# %%
x=df.drop('Species',axis="columns")
print(x)
y=df.Species
print(y)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# ...

# %% [markdown]
# # #make a graph
# #visualilze the  all data

# %% [markdown]
# # PetalLengthCm_Graph

# %% [markdown]
# # #PetalLength and species comperesion

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))

plt.suptitle("Species_Graph")
sns.violinplot(x='Species',y='PetalLengthCm',palette='husl',data=df)
sns.set_style("darkgrid")
plt.title("PetalLengthCm_Graph")

plt.show()

# %% [markdown]
# #  SepalLengthCm and PetalLengthCm comperesion

# %%
plt.figure(figsize=(10,5))

plt.suptitle("Species_Graph")
sns.violinplot(x='PetalLengthCm',y="SepalLengthCm",palette='husl',data=df)
sns.set_style("whitegrid")
plt.title("Length_Graph")
plt.show()

# %% [markdown]
# # make a  all in one graph

# %%
plt.figure(figsize=(8,4))
sns.pairplot(df.reset_index(), palette="husl", hue="Species", height=3)

sns.set_style("darkgrid")
plt.show()

# %%
# plot a heatmap of the correlated data
sns.heatmap(x)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # # preprocessing

# %% [markdown]
# # TRAIN DATA =80% AND TEST DATA =20%

# %% [markdown]
# # test_size=0.20,random_state=0

# %%
#split data

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %% [markdown]
# # standardizing features by removing the mean and scaling to unit variance

# %%
from sklearn .preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)
print(x_train)
# Out:
# [[-3.41283725e-01  1.54399532e-02 -1.19254753e-01  2.25126850e-01
#    3.56381749e-01]
#  [ 3.50852428e-01 -9.98450310e-02 -1.04039491e+00  1.13559562e-01
#   -2.86480506e-02]
#  [ 7.97391882e-01  1.05300481e+00 -1.19254753e-01  9.50314227e-01
#    1.12644135e+00]
#  [-1.65857511e+00 -1.36797986e+00  3.41315328e-01 -1.39259884e+00
#   -1.31208072e+00]
#  [ 1.44487409e+00  1.16828980e+00  1.11030287e-01  7.27179649e-01
#    1.38312788e+00]
#  [-7.43169234e-01 -1.02212490e+00  1.03217045e+00 -1.22524790e+00
#   -7.98707650e-01]
#  [-1.47995933e+00 -5.60984968e-01  1.49274053e+00 -1.28103155e+00
#   -1.31208072e+00]
#  [-3.63610698e-01 -1.02212490e+00 -2.42210516e+00 -1.65358660e-01
#   -2.85334584e-01]
#  [ 8.86699773e-01  7.07149859e-01 -1.19254753e-01  9.50314227e-01
#    7.41411549e-01]
#  [ 1.51185501e+00  9.37719827e-01  5.71600368e-01  1.06188152e+00
#    1.63981441e+00]
#  [ 9.53680691e-01  1.30724937e-01 -1.96153508e+00  6.71396005e-01
#    3.56381749e-01]
# ...

# %% [markdown]
# # #model train

# %% [markdown]
# # Logistic Regression:
#
# #LogisticRegression is a linear classification algorithm that models the probability of an instance belonging to a particular class.
# #It's commonly used for binary classification problems.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

model_1=LogisticRegression()
model_1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Decision Tree Classifier:
#
# #DecisionTreeClassifier is a non-linear classification algorithm that builds a tree-like model of decisions and their possible consequences.
# #It's capable of handling both binary and multi-class classification problems.

# %%
model_2 = DecisionTreeClassifier()
model_2.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Random Forest Classifier:
#
# RandomForestClassifier is an ensemble algorithm that combines multiple decision trees to make predictions.
# It's known for its robustness, as it reduces overfitting and provides higher accuracy compared to a single decision tree.

# %%
model_3 =RandomForestClassifier()
model_3.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # predict of model

# %% [markdown]
# # To make predictions using a trained model

# %%
pred_1 = model_1.predict(x_test)
pred_2 = model_2.predict(x_test)
pred_3 = model_3.predict(x_test)

# %% [markdown]
# # Calculate the accuracy of each model
#
#
# # Calculate the confusion matrix for each model

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
 # Calculate the accuracy of each model
print("accuracy_score of 1st model:-{0}%".format(accuracy_score(y_test,pred_1)*100))
print("accuracy_score of 2st model:-{0}%".format(accuracy_score(y_test,pred_2)*100))
print("accuracy_score of 3st model:-{0}%".format(accuracy_score(y_test,pred_3)*100))
# Out:
# accuracy_score of 1st model:-100.0%
# accuracy_score of 2st model:-100.0%
# accuracy_score of 3st model:-100.0%

# %%
# Calculate the confusion matrix for each model
print("confusion_matrix of 1st model:-{0}%".format(confusion_matrix(y_test,pred_1)))
print("confusion_matrix of 2st model:-{0}%".format(confusion_matrix(y_test,pred_2)))
print("confusion_matrix of 3st model:-{0}%".format(confusion_matrix(y_test,pred_3)))
# Out:
# confusion_matrix of 1st model:-[[13  0  0]
#  [ 0 16  0]
#  [ 0  0  9]]%
# confusion_matrix of 1st model:-[[13  0  0]
#  [ 0 16  0]
#  [ 0  0  9]]%
# confusion_matrix of 1st model:-[[13  0  0]
#  [ 0 16  0]
#  [ 0  0  9]]%
